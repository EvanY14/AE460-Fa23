# %% [markdown]
# # AE 460: Aerodynamics and Propulsion Laboratory #
#
# ## Turbojet Lab ##

# %% [markdown]
# ### Problem 1 ###

# %% [markdown]
# The compressor spins up prior to ignition such that the air in the combustion chamber is at high enough pressure, and therefore temperature to under go combustion when fuel is added. Once the compressor spins up the turbine and fuel is added, it was noticed that there is more smoke at the initial stages of the start up. This is due to the engine running fuel rich during start up to ensure ignition of the fuel. Once the engine is running and self sustaining, the fuel to air ratio is reduced to a more efficient level and the soot is reduced.

# %% [markdown]
# ### Problem 2 ###

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display, HTML

# %%
df = pd.read_csv('data.csv', sep='\t')
time = df['Time (sec)']
t1 = df['T1 (C)']
t2 = df['T2 (C)']
t3 = df['T3 (C)']
t4 = df['T4 (C)']
P1 = df['P1 (kPa)']
P2 = df['P2 (kPa)']
P3 = df['P3 (kPa)']
P4 = df['P4 (kPa)']
ff = df['Fuel Flow  (L/hr)']
rpm = df['RPM']
thrust = df['Thrust (N)']

# %%
plt.figure(figsize=(20, 10))
plt.plot(time, rpm)
plt.axvline(x=145, color='r', linestyle='--', label='Start of Idle Run')
plt.axvline(x=170, color='r', linestyle=':', label='End of Idle Run')
plt.axvline(x=215, color='g', linestyle='--', label='Start of 58000RPM Run')
plt.axvline(x=260, color='g', linestyle=':', label='End of 58000RPM Run')
plt.axvline(x=290, color='b', linestyle='--', label='Start of 68000RPM Run')
plt.axvline(x=320, color='b', linestyle=':', label='End of 68000RPM Run')
plt.axvline(x=327, color='black', linestyle='--', label='Start of Max RPM Run')
plt.axvline(x=351, color='black', linestyle=':', label='End of Max RPM Run')
plt.title('RPM vs Time')
plt.xlabel('Time (sec)')
plt.ylabel('RPM')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# In the phases where throttle was maintained at a constant power setting, the RPM remained fairly constant. During the start up phase, before the idle run, it is seen that RPM increases beyond the idle RPM setting before settling back down to the idle RPM.

# %% [markdown]
# ### Problem 3 ###

# %%
start_before = 0
end_before = 174
prestart_rpm_avg = np.average(rpm[start_before:end_before]) - np.average(rpm[start_before:end_before])
prestart_t1_avg = np.average(t1[start_before:end_before])
prestart_t2_avg = np.average(t2[start_before:end_before])
prestart_t3_avg = np.average(t3[start_before:end_before])
prestart_t4_avg = np.average(t4[start_before:end_before])
prestart_p1_avg = np.average(P1[start_before:end_before])
prestart_p2_avg = np.average(P2[start_before:end_before])
prestart_p3_avg = np.average(P3[start_before:end_before])
prestart_p4_avg = np.average(P4[start_before:end_before])
prestart_ff_avg = np.average(ff[start_before:end_before]) - np.average(ff[start_before:end_before])
prestart_thrust_avg = np.average(thrust[start_before:end_before]) - np.average(thrust[start_before:end_before])

start_idle = 324
end_idle = 449
idle_rpm_avg = np.average(rpm[start_idle:end_idle]) - np.average(rpm[start_before:end_before])
idle_t1_avg = np.average(t1[start_idle:end_idle])
idle_t2_avg = np.average(t2[start_idle:end_idle])
idle_t3_avg = np.average(t3[start_idle:end_idle])
idle_t4_avg = np.average(t4[start_idle:end_idle])
idle_p1_avg = np.average(P1[start_idle:end_idle])
idle_p2_avg = np.average(P2[start_idle:end_idle])
idle_p3_avg = np.average(P3[start_idle:end_idle])
idle_p4_avg = np.average(P4[start_idle:end_idle])
idle_ff_avg = np.average(ff[start_idle:end_idle]) - np.average(ff[start_before:end_before])
idle_thrust_avg = np.average(thrust[start_idle:end_idle]) - np.average(thrust[start_before:end_before])

turbojet = pd.DataFrame({"RPM":[prestart_rpm_avg, idle_rpm_avg],
                   "T1 (C)":[prestart_t1_avg, idle_t1_avg],
                   "T2 (C)":[prestart_t2_avg, idle_t2_avg],
                   "T3 (C)":[prestart_t3_avg, idle_t3_avg],
                   "T4 (C)":[prestart_t4_avg, idle_t4_avg],
                   "P1 (kPa)":[prestart_p1_avg, idle_p1_avg],
                   "P2 (kPa)":[prestart_p2_avg, idle_p2_avg],
                   "P3 (kPa)":[prestart_p3_avg, idle_p3_avg],
                   "P4 (kPa)":[prestart_p4_avg, idle_p4_avg],
                   "FF (L/hr)":[prestart_ff_avg, idle_ff_avg],
                   "Thrust (N)":[prestart_thrust_avg, idle_thrust_avg]},
                  index=["Prestart", "Idle"]).round(3)
display(HTML(turbojet.to_html(index=True)))

ambient_press = pd.DataFrame({"Ambient Pressure (kPa)":[106.8]})
ambient_temp = pd.DataFrame({"Ambient Temperature (C)":[19.5]})

display(HTML(ambient_press.to_html(index=False)))
display(HTML(ambient_temp.to_html(index=False)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>RPM</th>
#       <th>T1 (C)</th>
#       <th>T2 (C)</th>
#       <th>T3 (C)</th>
#       <th>T4 (C)</th>
#       <th>P1 (kPa)</th>
#       <th>P2 (kPa)</th>
#       <th>P3 (kPa)</th>
#       <th>P4 (kPa)</th>
#       <th>FF (L/hr)</th>
#       <th>Thrust (N)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Prestart</th>
#       <td>0.000</td>
#       <td>41.369</td>
#       <td>40.940</td>
#       <td>66.569</td>
#       <td>41.551</td>
#       <td>0.016</td>
#       <td>0.106</td>
#       <td>0.138</td>
#       <td>0.022</td>
#       <td>0.000</td>
#       <td>0.000</td>
#     </tr>
#     <tr>
#       <th>Idle</th>
#       <td>43422.882</td>
#       <td>21.231</td>
#       <td>69.729</td>
#       <td>524.082</td>
#       <td>254.651</td>
#       <td>1.318</td>
#       <td>45.197</td>
#       <td>44.840</td>
#       <td>5.364</td>
# ...
